# %% [markdown]
# # Problem Statement 1:
# In a survey conducted by a non-banking financial company, a sample of 200 customers yielded that x of them were highly satisfied with the timely disbursal of their loans.
#
# Write a Python code to perform the following operations:
#
# 1.Read an integer input that specifies the number of highly satisfied customers
#
# 2.Calculate an approximate 90% confidence interval for the proportion of the loan customers who are highly satisfied with disbursal time
#
# •Find out the Margin of Error using scipy.stats.norm.ppf
#
# •Calculate and print the confidence interval values rounded up to five decimal places and separated by a space
#
# Note:
#
# •Margin of Error = Critical Value * Standard Error of Statistic
#
# •Confidence Interval = Sample Statistic ± Margin of Error
#
# Example: Let's say 172 out of 200 customers were highly satisfied.
#
# Sample Input:
# 172
#
# The confidence interval should be printed as -
#
# Sample Output:
# 0.82856 0.89144

# %%
#pip install scipy

# %%
import scipy.stats as stats

x = int(input("Sample Input: \n"))

# Total sample size 
n = 200

# Calculating the sample proportion
p = x / n

# Setting the confidence level
confidence_level = 0.9

# Calculating the critical value
z_critical = stats.norm.ppf((1 + confidence_level) / 2)

# Calculating the standard error 
standard_error = (p * (1 - p) / n)**0.5

# Calculating the margin of error
margin_of_error = z_critical * standard_error

# Calculating the confidence interval
confidence_interval_lower = p - margin_of_error
confidence_interval_upper = p + margin_of_error

# Printing the confidence interval values rounded to five decimal places
print("Sample Output: \n", round(confidence_interval_lower, 5),round(confidence_interval_upper, 5))
# Out:
# Sample Input:
# 172
# Sample Output:
#  0.81964 0.90036

# %% [markdown]
# # Problem Statement 2:
# A radar unit is used to measure the speeds of cars on a motorway. The speeds are normally distributed with a mean of 75 km/hr and a standard deviation of 15 km/hr.
#
# Write a Python code to perform the following operations:
#
# 1.Find the probability that a car picked at random is traveling at more than X km/hr
#
# •Take the speed X as an input
#
# •Print the probability value rounded up tofour decimal places
#
# Hint:Use Normal Distribution.
#
# Sample Input:100
#
# Sample Output:0.0478

# %%
import scipy.stats as stats

speed_of_mean = 75 # mean speed in km/hr

speed_of_std_dev = 15 # standard deviation speed in km/hr

X = float(input("Sample Input: \n"))

# Calculate the probability that a car is traveling at more than X km/hr
probability_more_than_X = 1 - stats.norm.cdf(X, speed_of_mean,speed_of_std_dev)

# Print the probability rounded to four decimal places
print("Sample Output: \n",round(probability_more_than_X, 4))
# Out:
# Sample Input:
# 100
# Sample Output:
#  0.0478

# %% [markdown]
# # Problem Statement 3:
# Write a Python program to load the “kerala.csv”data into a DataFrameand perform the following tasks:

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\King\\Desktop\\DSML Internship\\Assignments\\Assignment 3\\kerala.csv")
df
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...     ...
# 113      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9
# 114      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2
# 115      KERALA  2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5
# 116     KERALA   2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8
# 117      KERALA  2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9
#
# ...

# %% [markdown]
# ## 1.Explore the DataFrame using info() and describe() functions

# %%
df.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   118.000000  118.000000  118.000000  118.000000  118.000000
# mean   1959.500000   12.218644   15.633898   36.670339  110.330508
# std      34.207699   15.473766   16.406290   30.063862   44.633452
# min    1901.000000    0.000000    0.000000    0.100000   13.100000
# 25%    1930.250000    2.175000    4.700000   18.100000   74.350000
# 50%    1959.500000    5.800000    8.350000   28.400000  110.400000
# 75%    1988.750000   18.175000   21.400000   49.825000  136.450000
# max    2018.000000   83.500000   79.000000  217.200000  238.000000
#
#               MAY          JUN          JUL          AUG         SEP  \
# count  118.000000   118.000000   118.000000   118.000000  118.000000
# mean   228.644915   651.617797   698.220339   430.369492  246.207627
# std    147.548778   186.181363   228.988966   181.980463  121.901131
# min     53.400000   196.800000   167.500000   178.600000   41.300000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBDIVISION       118 non-null    object
#  1   YEAR              118 non-null    int64
#  2   JAN               118 non-null    float64
#  3   FEB               118 non-null    float64
#  4   MAR               118 non-null    float64
#  5   APR               118 non-null    float64
#  6   MAY               118 non-null    float64
#  7   JUN               118 non-null    float64
#  8   JUL               118 non-null    float64
#  9   AUG               118 non-null    float64
#  10  SEP               118 non-null    float64
#  11  OCT               118 non-null    float64
#  12  NOV               118 non-null    float64
#  13  DEC               118 non-null    float64
#  14   ANNUAL RAINFALL  118 non-null    float64
#  15  FLOODS            118 non-null    object
# ...

# %% [markdown]
# ## 2.June and July are the peak months of rainfall. Consider that if it rains more than 500mm, then chances of flood become more;create a Datarame with columns –“YEAR”, “JUN_GT_500”(Contains a boolean value to showwhether it rained more than500 mm in the month of June), “JUL_GT_500”(Contains a boolean value to showwhether it rained more than500 mm in the month of July),and “FLOODS”(Containsaboolean value to showwhetherit flooded that year)

# %%
df['JUN_GT_500'] = df['JUN'] > 500
df['JUN_GT_500']=df['JUN_GT_500'].map({True:1,False:0})
df['JUN_GT_500'].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: JUN_GT_500, dtype: int64

# %%
df['JUL_GT_500'] = df['JUL']>500
df['JUL_GT_500']=df['JUL_GT_500'].map({True:1,False:0})
df['JUL_GT_500'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: JUL_GT_500, dtype: int64

# %%
df['Floods']=df['FLOODS'].map({'YES':1,'NO':0})

# %%
df.head()
# Out:
#   SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 0      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 1      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 2      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 4      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
#
#      SEP    OCT    NOV    DEC   ANNUAL RAINFALL FLOODS  JUN_GT_500  \
# 0  197.7  266.9  350.8   48.4            3248.6    YES           1
# 1  491.6  358.4  158.3  121.5            3326.6    YES           0
# 2  341.8  354.1  157.0   59.0            3271.2    YES           1
# 3  222.7  328.1   33.9    3.3            3129.7    YES           1
# 4  217.2  383.5   74.4    0.2            2741.6     NO           1
#
#    JUL_GT_500  Floods
# 0           1       1
# 1           1       1
# 2           1       1
# ...

# %%
df1=df[['YEAR','JUN_GT_500','JUL_GT_500','Floods']]
df1.head()
# Out:
#    YEAR  JUN_GT_500  JUL_GT_500  Floods
# 0  1901           1           1       1
# 1  1902           0           1       1
# 2  1903           1           1       1
# 3  1904           1           1       1
# 4  1905           1           1       0

# %% [markdown]
# ## 3.Calculate the probability of flood given it rained more than 500 mm in June (P(A|B))

# %%
len(df1[(df1.Floods==1)&df1.JUN_GT_500==1])/len(df1[df1.JUN_GT_500==1])
# Out:
# 0.5806451612903226

# %% [markdown]
# ## 4.Calculate the probability of rain more than 500 mm in June, given it flooded that year (P(B|A))

# %%
len(df1[(df1.Floods==1)&df1.JUN_GT_500==1])/len(df1[df1.Floods==1])
# Out:
# 0.9

# %% [markdown]
# ## 5.Probability of flood given it rained more than 500 mm in July

# %%
len(df1[(df1.Floods==1)&df1.JUL_GT_500==1])/len(df1[df1.JUL_GT_500==1])
# Out:
# 0.59375

# %% [markdown]
# ## 6.Probability of rain more than 500 mm in July given it flooded that year (P(B|A))

# %%
len(df1[(df1.Floods==1)&df1.JUL_GT_500==1])/len(df1[df1.Floods==1])
# Out:
# 0.95

# %% [markdown]
# # Problem Statement 4:
# Write a Python program to load the wine dataset using the Sklearn library to a DataFrame and perform the following tasks:
#
# 1.Convert the dataset into DataFrame using pandas.
#
# 2.Generate the sample size of 50and give a randomstate as 100.
#
# 3.Calculate Z-critical, Margin of Error,and Confidence Interval for alcohol at 95% significance interval on generated sample data.

# %%
from sklearn.datasets import load_wine

# %%
wine = load_wine

# %% [markdown]
# ## 1.Convert the dataset into DataFrame using pandas.

# %%
import pandas as pd

# Load the wine dataset
wine_data = load_wine()

# Convert the dataset into a DataFrame
df = pd.DataFrame(data=wine_data.data, columns=wine_data.feature_names)
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# ## 2.Generate the sample size of 50 and give a randomstate as 100.

# %%
df1=df.sample(n=50,random_state=100) # n is sample size
df1.head()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 88     11.64        2.06  2.46               21.6       84.0           1.95
# 159    13.48        1.67  2.64               22.5       89.0           2.60
# 11     14.12        1.48  2.32               16.8       95.0           2.20
# 74     11.96        1.09  2.30               21.0      101.0           3.38
# 158    14.34        1.68  2.70               25.0       98.0           2.80
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 88         1.69                  0.48             1.35             2.80  1.00
# 159        1.10                  0.52             2.29            11.75  0.57
# 11         2.43                  0.26             1.57             5.00  1.17
# 74         2.14                  0.13             1.65             3.21  0.99
# 158        1.31                  0.53             2.70            13.00  0.57
#
# ...

# %% [markdown]
# ## 3.Calculate Z-critical, Margin of Error,and Confidence Interval for alcohol at 95% significance interval on generated sample data.

# %%
from scipy import stats

# %%
# confidence_level = 0.95

# %%
# Calculating Z-critical value
z_critical = stats.norm.ppf(0.95)
z_critical
# Out:
# 1.6448536269514722

# %%
# Calculating margin of error
margin_of_error = z_critical * ((df['alcohol'].std())/np.sqrt(50))
margin_of_error
# Out:
# 0.18884500347368421

# %%
df['alcohol'].mean()-margin_of_error,df['alcohol'].mean()+margin_of_error
# Out:
# (12.811772974054406, 13.189462981001775)
